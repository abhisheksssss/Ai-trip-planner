# %%
print("Hii")
# Out:
# Running cells with 'genaihindi (Python 3.8.20)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n genaihindi ipykernel --update-deps --force-reinstall'
